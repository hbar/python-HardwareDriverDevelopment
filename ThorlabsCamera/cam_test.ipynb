# %%
import uc480
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cam = uc480.uc480()
# Out:
# Load uc480 library..
# querying is_GetDLLVersion..
# API version 4.80.5
# calling is_GetNumberOfCameras..
# Found 1 camera(s)
# calling is_GetCameraList..
# Camera #0: SerNo = b'4102903985', CameraID = 1, DeviceID = 1

# %%
cam.connect()
# Out:
# calling is_InitCamera..
# calling is_GetSensorInfo..
# calling is_SetColorMode..
# Sensor: 1280 x 1024 pixels, RGB = 1, 24 bits/px
# calling is_Exposure..
# Valid exposure times: 0.062417ms to 99.866667ms in steps of 0.062417ms
# calling is_ResetToDefault..
# calling is_SetExternalTrigger..
# calling is_SetGainBoost..
# calling is_SetHardwareGain..
# calling is_Exposure..
# calling is_SetDisplayMode..
# calling is_AllocImageMem..
# calling is_SetImageMem..

# %%
cam.set_exposure(1)
# Out:
# calling is_Exposure..

# %%
img = cam.acquire()
plt.imshow(img)
# Out:
# acquire 1 frames
#   wait for data..
# querying is_FreezeVideo..
#   read data..
# calling is_CopyImageMem..
